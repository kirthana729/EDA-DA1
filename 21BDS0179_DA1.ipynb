# %% [markdown]
# <a href="https://colab.research.google.com/github/kirthana729/EDA-DA1/blob/main/21BDS0179_DA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : G.Kirthana Reg no: 21BDS0179

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/content/elem94_95.csv'
data = pd.read_csv(file_path)

# Step 1: Inspecting the Dataset
print("\nBasic Information about the Dataset:")
print(data.info())  # Summary of the dataset structure
print("\nSummary Statistics for Numerical Columns:")
print(data.describe())  # Descriptive statistics
print("\nFirst Few Rows of the Dataset:")
print(data.head())  # First few rows

# Step 2: Identifying Data Types
print("\nIdentifying Data Types:")
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_columns = data.select_dtypes(include=['object']).columns.tolist()
print(f"Numerical Columns: {numerical_columns}")
print(f"Categorical Columns: {categorical_columns}")

# Step 3: Numerical Data Analysis (Discrete vs. Continuous)
print("\nAnalyzing Numerical Data:")
for col in numerical_columns:
    print(f"\nColumn: {col}")
    print(f"Unique Values: {data[col].nunique()}")
    print(f"Is Discrete: {data[col].nunique() <= 20}")

# Step 4: Categorical Data Analysis
print("\nAnalyzing Categorical Data:")
for col in categorical_columns:
    print(f"\nColumn: {col}")
    print(f"Unique Categories: {data[col].unique()}")
    print(f"Category Counts:\n{data[col].value_counts()}")

# Step 5: Measurement Scales
print("\nUnderstanding Measurement Scales:")
# Manual assignment based on context (requires domain knowledge)
scales = {
    "Nominal": categorical_columns,  # Replace as needed
    "Ordinal": [],  # Add ordinal columns if known
    "Interval": [],  # Add interval columns if applicable
    "Ratio": numerical_columns,  # Typically numerical columns
}
print(f"Scales Assigned:\n{scales}")

# Step 6: EDA Visualizations
# Correlation Matrix for Numerical Data
plt.figure(figsize=(10, 6))
sns.heatmap(data[numerical_columns].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# Distribution Plots for Numerical Data
for col in numerical_columns:
    sns.histplot(data[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# Count Plots for Categorical Data
for col in categorical_columns:
    sns.countplot(x=col, data=data)
    plt.title(f"Count Plot for {col}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Basic Information about the Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1848 entries, 0 to 1847
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  1848 non-null   int64
#  1   distid    1848 non-null   int64
#  2   schid     1848 non-null   int64
#  3   lunch     1848 non-null   float64
#  4   enrol     1848 non-null   int64
#  5   staff     1848 non-null   float64
#  6   exppp     1848 non-null   int64
#  7   avgsal    1848 non-null   int64
#  8   avgben    1848 non-null   int64
#  9   math4     1848 non-null   float64
#  10  story4    1848 non-null   float64
#  11  bs        1848 non-null   float64
#  12  lavgsal   1848 non-null   float64
#  13  lenrol    1848 non-null   float64
#  14  lstaff    1848 non-null   float64
# dtypes: float64(8), int64(7)
# memory usage: 216.7 KB
# None
#
# Summary Statistics for Numerical Columns:
# ...
